# %%
import EC_data as EC

# %%
EC.plot(0, sep='	', specialpotential='Ewe/V', specialcurrent='I/mA')
# Out:
# Potenciais de pico:   [0.1990000009536743, 0.1419999897480011]
# Correntes de pico:   [3198.491176590323, -4028.1862020492554]
# C:\Users\icarus\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:1239: RuntimeWarning:
#
# divide by zero encountered in divide
#
# C:\Users\icarus\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:1241: RuntimeWarning:
#
# divide by zero encountered in divide
#
# C:\Users\icarus\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:1247: RuntimeWarning:
#
# invalid value encountered in add

# %%
EC.peaks(4, 'viridis', sep='	', specialpotential='Ewe/V', specialcurrent='I/mA')
# Out:
# array([], dtype=float64)
